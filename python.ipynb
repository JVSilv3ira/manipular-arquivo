# %%
entrada = input("Digite algo: ")
with open('dados/arquivo01.txt', 'a', encoding='utf-8') as f:
    f.write(entrada + "\n")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 entrada = input("Digite algo: ")
#       2 with open('dados/arquivo01.txt', 'a', encoding='utf-8') as f:
#       3     f.write(entrada + "\n")
#
# TypeError: 'str' object is not callable
